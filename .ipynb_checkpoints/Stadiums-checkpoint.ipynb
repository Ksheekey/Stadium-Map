# %%
#dependencies
from pprint import pprint
import pandas as pd
import numpy as np
import time
import timeit
import requests
import json
import re
from config import gkey

# start program run timer
start = timeit.default_timer()

# setting variables
arena_ltlg = []
x = 0

# %% [markdown]
# # NHL

# %%
# pulling the table and columns wanted
NHLurl = 'https://en.wikipedia.org/wiki/List_of_National_Hockey_League_arenas'
tables = pd.read_html(NHLurl, header=[0])
NHLdf = tables[0]
NHLteam_arena = NHLdf[['Team','Arena']]

# column cleanup
NHLteam_arena['ArenaAPI'] = [re.sub(r'\s+', '%20', x) for x in NHLteam_arena['Arena']]
NHLteam_arena['ArenaAPI'] = NHLteam_arena['ArenaAPI'].replace({'&': ''}, regex=True)

# for loop to build data structure
for arena in NHLteam_arena['ArenaAPI']:
    # found some location accuracy issues so fixed them 
    # Fixing Pittsburgh Penguins
    if arena == 'PPG%20Paints%20Arena':
        arena = 'PPG%20Arena'
    # Fixing Edmonton Oilers
    if arena == 'Rogers%20Place':
        arena = 'Rogers%20Place%20Arena'
    target_arena = arena

    # Build the endpoint URL
    target_url = (f'https://maps.googleapis.com/maps/api/geocode/json?'
        'address={0}&key={1}').format(target_arena, gkey)
    geo_data = requests.get(target_url).json()
    lat = geo_data['results'][0]['geometry']['location']['lat']
    lng = geo_data['results'][0]['geometry']['location']['lng']
    address = geo_data['results'][0]['formatted_address']
    arena_ltlg.append({"team" : NHLteam_arena['Team'][x],
                     "location" : [lat, lng],
                     "address" : address,
                     "arena" : NHLteam_arena['Arena'][x],
                      "sport" : "NHL"})
    x+=1
    
pprint(arena_ltlg)
# Out:
# <ipython-input-2-5e7075a1103d>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NHLteam_arena['ArenaAPI'] = [re.sub(r'\s+', '%20', x) for x in NHLteam_arena['Arena']]
# <ipython-input-2-5e7075a1103d>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NHLteam_arena['ArenaAPI'] = NHLteam_arena['ArenaAPI'].replace({'&': ''}, regex=True)
# [{'address': '401 Channelside Dr, Tampa, FL 33602, USA',
#   'arena': 'Amalie Arena',
#   'location': [27.9427373, -82.4517771],
#   'sport': 'NHL',
#   'team': 'Tampa Bay Lightning'},
#  {'address': '2500 Victory Ave, Dallas, TX 75219, USA',
#   'arena': 'American Airlines Center',
#   'location': [32.7903908, -96.8102547],
#   'sport': 'NHL',
#   'team': 'Dallas Stars'},
#  {'address': '1000 Chopper Cir, Denver, CO 80204, USA',
#   'arena': 'Ball Arena',
#   'location': [39.7486565, -105.0076028],
#   'sport': 'NHL',
#   'team': 'Colorado Avalanche'},
#  {'address': '1909 Av. des Canadiens-de-Montréal, Montréal, QC H3B 5E8, Canada',
#   'arena': 'Bell Centre',
#   'location': [45.4960667, -73.5693153],
#   'sport': 'NHL',
#   'team': 'Montreal Canadiens'},
#  {'address': '501 Broadway, Nashville, TN 37203, USA',
#   'arena': 'Bridgestone Arena',
#   'location': [36.1591736, -86.7784959],
#   'sport': 'NHL',
#   'team': 'Nashville Predators'},
#  {'address': '345 Graham Ave, Winnipeg, MB R3C 5S6, Canada',
#   'arena': 'Canada Life Centre',
#   'location': [49.8926443, -97.14376240000001],
#   'sport': 'NHL',
#   'team': 'Winnipeg Jets'},
#  {'address': '1000 Palladium Dr, Ottawa, ON K2V 1A5, Canada',
#   'arena': 'Canadian Tire Centre',
#   'location': [45.2969151, -75.926823],
#   'sport': 'NHL',
#   'team': 'Ottawa Senators'},
#  {'address': '601 F St NW, Washington, DC 20004, USA',
#   'arena': 'Capital One Arena',
#   'location': [38.8981675, -77.02085679999999],
#   'sport': 'NHL',
#   'team': 'Washington Capitals'},
#  {'address': '334 1st Ave N, Seattle, WA 98109, USA',
#   'arena': 'Climate Pledge Arena',
#   'location': [47.62207129999999, -122.3540714],
#   'sport': 'NHL',
#   'team': 'Seattle Kraken'},
#  {'address': '1401 Clark Ave, St. Louis, MO 63103, USA',
#   'arena': 'Enterprise Center',
#   'location': [38.6268402, -90.20267830000002],
#   'sport': 'NHL',
#   'team': 'St. Louis Blues'},
#  {'address': '1 Panther Pkwy, Sunrise, FL 33323, USA',
#   'arena': 'FLA Live Arena',
#   'location': [26.1584958, -80.3255204],
#   'sport': 'NHL',
#   'team': 'Florida Panthers'},
#  {'address': '9400 W Maryland Ave, Glendale, AZ 85305, USA',
#   'arena': 'Gila River Arena',
#   'location': [33.532074, -112.2612163],
#   'sport': 'NHL',
#   'team': 'Arizona Coyotes'},
#  {'address': '2695 E Katella Ave, Anaheim, CA 92806, USA',
#   'arena': 'Honda Center',
#   'location': [33.8078476, -117.8764687],
#   'sport': 'NHL',
#   'team': 'Anaheim Ducks'},
#  {'address': '1 Seymour H Knox III Plaza, Buffalo, NY 14203, USA',
#   'arena': 'KeyBank Center',
#   'location': [42.8750811, -78.8765439],
#   'sport': 'NHL',
#   'team': 'Buffalo Sabres'},
#  {'address': '2645 Woodward Ave, Detroit, MI 48201, USA',
#   'arena': 'Little Caesars Arena',
#   'location': [42.3411026, -83.0552673],
#   'sport': 'NHL',
#   'team': 'Detroit Red Wings'},
#  {'address': '4 Pennsylvania Plaza, New York, NY 10001, USA',
#   'arena': 'Madison Square Garden',
#   'location': [40.7505045, -73.9934387],
#   'sport': 'NHL',
#   'team': 'New York Rangers'},
#  {'address': '200 W Nationwide Blvd, Columbus, OH 43215, USA',
#   'arena': 'Nationwide Arena',
#   'location': [39.9692072, -83.0060483],
#   'sport': 'NHL',
#   'team': 'Columbus Blue Jackets'},
#  {'address': '1400 Edwards Mill Rd, Raleigh, NC 27607, USA',
#   'arena': 'PNC Arena',
#   'location': [35.803329, -78.7218018],
#   'sport': 'NHL',
#   'team': 'Carolina Hurricanes'},
#  {'address': '1001 Fifth Ave, Pittsburgh, PA 15219, USA',
#   'arena': 'PPG Paints Arena',
#   'location': [40.4393097, -79.98955289999999],
#   'sport': 'NHL',
#   'team': 'Pittsburgh Penguins'},
#  {'address': '25 Lafayette St, Newark, NJ 07102, USA',
#   'arena': 'Prudential Center',
#   'location': [40.733537, -74.1710659],
#   'sport': 'NHL',
#   'team': 'New Jersey Devils'},
#  {'address': '800 Griffiths Way, Vancouver, BC V6B 6G1, Canada',
#   'arena': 'Rogers Arena',
#   'location': [49.2778358, -123.1088227],
#   'sport': 'NHL',
#   'team': 'Vancouver Canucks'},
#  {'address': '10220 104 Ave NW, Edmonton, AB T5J 0H6, Canada',
#   'arena': 'Rogers Place',
#   'location': [53.54697549999999, -113.4978004],
#   'sport': 'NHL',
#   'team': 'Edmonton Oilers'},
#  {'address': '525 W Santa Clara St, San Jose, CA 95113, USA',
#   'arena': 'SAP Center',
#   'location': [37.3327507, -121.9012447],
#   'sport': 'NHL',
#   'team': 'San Jose Sharks'},
#  {'address': '40 Bay St., Toronto, ON M5J 2X2, Canada',
#   'arena': 'Scotiabank Arena',
#   'location': [43.6434661, -79.3790989],
#   'sport': 'NHL',
#   'team': 'Toronto Maple Leafs'},
#  {'address': '555 Saddledome Rise SE, Calgary, AB T2G 2W1, Canada',
#   'arena': 'Scotiabank Saddledome',
#   'location': [51.0374336, -114.0519341],
#   'sport': 'NHL',
#   'team': 'Calgary Flames'},
#  {'address': '1111 S Figueroa St, Los Angeles, CA 90015, USA',
#   'arena': 'Staples Center',
#   'location': [34.0430175, -118.2672541],
#   'sport': 'NHL',
#   'team': 'Los Angeles Kings'},
#  {'address': '100 Legends Way, Boston, MA 02114, USA',
#   'arena': 'TD Garden',
#   'location': [42.366198, -71.062146],
#   'sport': 'NHL',
#   'team': 'Boston Bruins'},
#  {'address': '3780 Las Vegas Blvd S, Las Vegas, NV 89158, USA',
#   'arena': 'T-Mobile Arena',
#   'location': [36.1031582, -115.1787806],
#   'sport': 'NHL',
#   'team': 'Vegas Golden Knights'},
#  {'address': '2150 Hempstead Turnpike, Elmont, NY 11003, USA',
#   'arena': 'UBS Arena',
#   'location': [40.7117992, -73.72619399999999],
#   'sport': 'NHL',
#   'team': 'New York Islanders'},
#  {'address': '1901 W Madison St, Chicago, IL 60612, USA',
#   'arena': 'United Center',
#   'location': [41.8806908, -87.6741759],
#   'sport': 'NHL',
#   'team': 'Chicago Blackhawks'},
#  {'address': '3601 S Broad St, Philadelphia, PA 19148, USA',
#   'arena': 'Wells Fargo Center',
#   'location': [39.9012015, -75.17197949999999],
#   'sport': 'NHL',
#   'team': 'Philadelphia Flyers'},
#  {'address': '199 W Kellogg Blvd, St Paul, MN 55102, USA',
#   'arena': 'Xcel Energy Center',
#   'location': [44.944596, -93.100167],
#   'sport': 'NHL',
#   'team': 'Minnesota Wild'}]

# %% [markdown]
# # NFL

# %%
NFLurl = 'https://en.wikipedia.org/wiki/List_of_current_National_Football_League_stadiums'
tables = pd.read_html(NFLurl, header=[0])
NFLdf = tables[0]
NFLteam_arena = NFLdf[['Team(s)','Name']]

NFLteam_arena['ArenaAPI'] = [re.sub(r'\s+', '%20', x) for x in NFLteam_arena['Name']]
NFLteam_arena['ArenaAPI'] = NFLteam_arena['ArenaAPI'].replace({'&': ''}, regex=True)

x = 0
for arena in NFLteam_arena['ArenaAPI'] :
    target_arena = arena

    target_url = (f'https://maps.googleapis.com/maps/api/geocode/json?'
        'address={0}&key={1}').format(target_arena, gkey)
    geo_data = requests.get(target_url).json()
    if target_arena != 'Highmark%20Stadium':
        lat = geo_data['results'][0]['geometry']['location']['lat']
        lng = geo_data['results'][0]['geometry']['location']['lng']
        address = geo_data['results'][0]['formatted_address']
    # Fixing Buffalo Bills
    else:
        lat = geo_data['results'][1]['geometry']['location']['lat']
        lng = geo_data['results'][1]['geometry']['location']['lng']
        address = geo_data['results'][1]['formatted_address']
    arena_ltlg.append({"team" : NFLteam_arena['Team(s)'][x],
                     "location" : [lat, lng],
                       "address" : address,
                     "arena" : NFLteam_arena['Name'][x],
                      "sport" : "NFL"})
    x+=1

# pprint(arena_ltlg)
# Out:
# <ipython-input-3-d6852a1c4046>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NFLteam_arena['ArenaAPI'] = [re.sub(r'\s+', '%20', x) for x in NFLteam_arena['Name']]
# <ipython-input-3-d6852a1c4046>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NFLteam_arena['ArenaAPI'] = NFLteam_arena['ArenaAPI'].replace({'&': ''}, regex=True)

# %% [markdown]
# # MLB

# %%
MLBurl = 'https://en.wikipedia.org/wiki/List_of_current_Major_League_Baseball_stadiums'
tables = pd.read_html(MLBurl, header=[0])
MLBdf = tables[1]
MLBteam_arena = MLBdf[['Team','Name']]

MLBteam_arena['ArenaAPI'] = [re.sub(r'\s+', '%20', x) for x in MLBteam_arena['Name']]
MLBteam_arena['Team'] = MLBteam_arena['Team'].replace({'nb 2': '', 'nb 3':''}, regex=True)
MLBteam_arena['Team'] = MLBteam_arena['Team'].str.replace('[', '')
MLBteam_arena['Team'] = MLBteam_arena['Team'].str.replace(']', '')

x = 0
for arena in MLBteam_arena['ArenaAPI']:
    target_arena = arena

    target_url = (f'https://maps.googleapis.com/maps/api/geocode/json?'
        'address={0}&key={1}').format(target_arena, gkey)
    geo_data = requests.get(target_url).json()
    lat = geo_data['results'][0]['geometry']['location']['lat']
    lng = geo_data['results'][0]['geometry']['location']['lng']
    address = geo_data['results'][0]['formatted_address']
    arena_ltlg.append({"team" : MLBteam_arena['Team'][x],
                     "location" : [lat, lng],
                       "address" : address,
                     "arena" : MLBteam_arena['Name'][x],
                      "sport" : "MLB"})
    x+=1

# pprint(arena_ltlg)
# Out:
# <ipython-input-4-892679a48f15>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MLBteam_arena['ArenaAPI'] = [re.sub(r'\s+', '%20', x) for x in MLBteam_arena['Name']]
# <ipython-input-4-892679a48f15>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MLBteam_arena['Team'] = MLBteam_arena['Team'].replace({'nb 2': '', 'nb 3':''}, regex=True)
# <ipython-input-4-892679a48f15>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MLBteam_arena['Team'] = MLBteam_arena['Team'].str.replace('[', '')
# <ipython-input-4-892679a48f15>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MLBteam_arena['Team'] = MLBteam_arena['Team'].str.replace(']', '')

# %% [markdown]
# # NBA

# %%
NBAurl = 'https://en.wikipedia.org/wiki/List_of_National_Basketball_Association_arenas'
tables = pd.read_html(NBAurl, header=[0])
NBAdf = tables[0]
NBAteam_arena = NBAdf[['Team(s)','Arena']]

NBAteam_arena['ArenaAPI'] = [re.sub(r'\s+', '%20', x) for x in NBAteam_arena['Arena']]
NBAteam_arena['ArenaAPI'] = NBAteam_arena['ArenaAPI'].replace({'&': ''}, regex=True)

x = 0
for arena in NBAteam_arena['ArenaAPI']:
    target_arena = arena

    target_url = (f'https://maps.googleapis.com/maps/api/geocode/json?'
        'address={0}&key={1}').format(target_arena, gkey)
    geo_data = requests.get(target_url).json()
    lat = geo_data['results'][0]['geometry']['location']['lat']
    lng = geo_data['results'][0]['geometry']['location']['lng']
    address = geo_data['results'][0]['formatted_address']
    arena_ltlg.append({"team" : NBAteam_arena['Team(s)'][x],
                     "location" : [lat, lng],
                       "address" : address,
                     "arena" : NBAteam_arena['Arena'][x],
                      "sport" : "NBA"})
    x+=1

# pprint(arena_ltlg)
# Out:
# <ipython-input-5-9f1593f2213c>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NBAteam_arena['ArenaAPI'] = [re.sub(r'\s+', '%20', x) for x in NBAteam_arena['Arena']]
# <ipython-input-5-9f1593f2213c>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NBAteam_arena['ArenaAPI'] = NBAteam_arena['ArenaAPI'].replace({'&': ''}, regex=True)

# %% [markdown]
# # MLS

# %%
MLSurl = 'https://en.wikipedia.org/wiki/List_of_Major_League_Soccer_stadiums'
tables = pd.read_html(MLSurl, header=[0])
MLSdf = tables[1]
MLSteam_arena = MLSdf[['Franchise','Stadium']]

MLSteam_arena['ArenaAPI'] = [re.sub(r'\s+', '%20', x) for x in MLSteam_arena['Stadium']]

x = 0
for arena in MLSteam_arena['ArenaAPI']:
    # Fixing Portland Timbers
    if arena == 'Providence%20Park':
        arena = 'Providence%20Park%20Arena'
    target_arena = arena

    target_url = (f'https://maps.googleapis.com/maps/api/geocode/json?'
        'address={0}&key={1}').format(target_arena, gkey)
    geo_data = requests.get(target_url).json()
    lat = geo_data['results'][0]['geometry']['location']['lat']
    lng = geo_data['results'][0]['geometry']['location']['lng']
    address = geo_data['results'][0]['formatted_address']
    arena_ltlg.append({"team" : MLSteam_arena['Franchise'][x],
                     "location" : [lat, lng],
                       "address" : address,
                     "arena" : MLSteam_arena['Stadium'][x],
                      "sport" : "MLS"})
    x+=1

# pprint(arena_ltlg)
# Out:
# <ipython-input-6-33dd64b3feec>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MLSteam_arena['ArenaAPI'] = [re.sub(r'\s+', '%20', x) for x in MLSteam_arena['Stadium']]

# %% [markdown]
# # NASCAR

# %%
NSCRurl = 'https://en.wikipedia.org/wiki/List_of_NASCAR_tracks'
tables = pd.read_html(NSCRurl, header=[0])
NSCRdf = tables[0]
NSCRtrack = NSCRdf[['Track']]

NSCRtrack['Track'] = NSCRtrack['Track'].replace({'Road Course': ''}, regex=True)
NSCRtrack['Track'] = NSCRtrack['Track'].str.replace('(', '')
NSCRtrack['Track'] = NSCRtrack['Track'].str.replace(')', '')
NSCRtrack.drop(NSCRtrack.index[[3,7]], inplace=True)
NSCRtrack.reset_index(drop=True, inplace=True)
NSCRtrack['ArenaAPI'] = [re.sub(r'\s+', '%20', x) for x in NSCRtrack['Track']]

x = 0
for arena in NSCRtrack['ArenaAPI']:
    target_arena = arena

    target_url = (f'https://maps.googleapis.com/maps/api/geocode/json?'
        'address={0}&key={1}').format(target_arena, gkey)
    geo_data = requests.get(target_url).json()
    lat = geo_data['results'][0]['geometry']['location']['lat']
    lng = geo_data['results'][0]['geometry']['location']['lng']
    address = geo_data['results'][0]['formatted_address']
    arena_ltlg.append({"track" : NSCRtrack['Track'][x],
                     "location" : [lat, lng],
                     "address" : address,
                     "sport" : "NASCAR"})
    x+=1

    
# pprint(arena_ltlg)
# Out:
# <ipython-input-7-3f30eda47efd>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NSCRtrack['Track'] = NSCRtrack['Track'].replace({'Road Course': ''}, regex=True)
# <ipython-input-7-3f30eda47efd>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NSCRtrack['Track'] = NSCRtrack['Track'].str.replace('(', '')
# <ipython-input-7-3f30eda47efd>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NSCRtrack['Track'] = NSCRtrack['Track'].str.replace(')', '')
# /Users/Kaboni/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# <ipython-input-7-3f30eda47efd>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NSCRtrack['ArenaAPI'] = [re.sub(r'\s+', '%20', x) for x in NSCRtrack['Track']]

# %%
with open('arenaInfo.json', 'w') as f:
    json.dump(arena_ltlg, f)

# %%
# stop program run timer
stop = timeit.default_timer()

# view how long it took to run
# try and find improvments to speed up later
print('Time to run:', stop - start, 'seconds')
# Out:
# Time to run: 85.86283077900003 seconds
